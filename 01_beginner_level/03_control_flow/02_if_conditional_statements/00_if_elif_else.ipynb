# %% [markdown]
# # Conditional statements (making decision)
# ## - checkpoint to check the conditions
# - standlaone if
# - two way path (if ..else)

# %%
score = 96
if score >= 90:
    print(f'Grade A')
    '''indendation at the beginning of your code to tell 
    python this block of code belongs to this functions, loop, conditional statements'''
# Out:
# Grade A

# %%
score = 50
if score >= 90:
    print(f'Grade A')
else:
    print(f'Grade E')
# Out:
# Grade E
