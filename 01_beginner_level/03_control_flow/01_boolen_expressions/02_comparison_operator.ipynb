# %%
'''
Comparison operator
    - Compoares two values and return true or false

Syntax:
    - value OPERATOR value ? True/ False

'''

print(3 > 5)
# Out:
# False

# %%
'''
Chained Comparsion
    - combines mutiple comparison in one line
    - evalutes from left to right
    - similiar to sql between(boundary?)
'''

print(4 <= 7 < 8)
# Out:
# True
