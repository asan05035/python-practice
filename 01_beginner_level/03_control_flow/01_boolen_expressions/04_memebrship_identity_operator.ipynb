# %%
'''
Membership operator
    - in and not in
    - check if a vlaue matches any value in the sequence(list in case of sql)
    - similiar in operator in sql to make filter dynamic

'''

# %%
'''
use_case: validating: Check if email is not in banned list
'''

banned_list = ['@spam.com', '@tempmail.com']
user_email = '@gmail.com'

user_email not in banned_list
# Out:
# True

# %%
'''
Idenity operator
    - check if two or more variable points to the same object in the memory
    - is and is not
    - difference between == and is 

'''

# %%
a = [1, 2, 4]
b = [1, 2, 4]

a == b #compare value
# Out:
# True

# %%
a is b # compare id
# Out:
# False

# %%
'''
Make sure email exist, it is not empty( sql is not null)
None vs empty string vs blank space
'''


user_email is not None and user_email != ''
# Out:
# True
