# %%
'''
Logical operator
    - Is used to combine tow or more conditions
    - and when both condition are true
    - or when atleast one condition is true
'''

# %%
3 > 2 and 5 == 5
# Out:
# True

# %%
# checking user credential before login

email = True
password = False

print(email and password)
# Out:
# False

# %%
# Execution order || paranthesis
# and operator has higher prority than or
# use paranthesis to control the order 

9> 6 and (6 > 7 or 5 == 5)
# Out:
# True

# %%
'''
Allow access only if the user is logged in or they are guest 
but they must not be banned
'''

is_logged_in = False
is_guest = True
is_banned = False
print((is_logged_in or is_guest) and not is_banned)
# Out:
# True
