# %% [markdown]
# # control flow statements
#
# ## controls how the code runs

# %%
x = 6
print(x)
# Out:
# 6

# %% [markdown]
# ## 1_conditional_statements
#
# ### 1.1_decision_making
#
# #### if
# #### if else
# #### else if
#
# ### 1.2 repeated tasks
#
# #### for loop
# #### while loop

# %%
x = 'ANNA'

if x.isupper():
    x = x.lower()
    print(x)
# Out:
# anna

# %% [markdown]
# ## 2.boolean expressions
#
# ### 2.1 comparision operator
# ### 2.2 logical operator
# ### 2.3 membership operator
# ### 2.4 identity operator
# ### 2.5 functions and values
