# %% [markdown]
# # Data types
# ## Different data types:: different boxes
# ## Different data types :: same boxes

# %%
# Conveyor belt (functions) problem
# - same conveyor belt will behave different depends on the box type

a = '1'
b = '2'

a + b
# Out:
# '12'

# %%
a = 1
b = 2

a + b
# Out:
# 3

# %% [markdown]
# # some conveyor belt are reserved for some boxes
# ## bus vs car

# %%
a = 'Hello'

a.upper()
# Out:
# 'HELLO'

# %%
'''
Function - independant block of code
    sybtax : function(value)

Method - function belong to class
    syntax: value.function()


'''

# %%
type('hello')
type(50)
# Out:
# int

# %%
number = 50

'hello'.upper()
number.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 4
#       1 number = 50
#       3 'hello'.upper()
# ----> 4 number.upper()
#
# AttributeError: 'int' object has no attribute 'upper'

# %%
number.bit_length()
# Out:
# 6

# %%
""" Value, datatype, length"""

# %%
student = None
print(student)
type(student)
# len(student)
# Out:
# None
# NoneType
