# %%
'''
Variables
    - Placeholder to store values that can be used later

'''
# Out:
# '\nVariables\n    - Placeholder to store values that can be used later\n\n'

# %%
print(f'My name is baara')
print(f'Baara is learning python')
print(f'Baara is trying to become python expert')
# Out:
# My name is baara
# Baara is learning python
# Baara is trying to become python expert

# %%
'''
If u repeat something in your code then it is a sign that code should be improved
'''

# %%
name = 'baara'
language = 'sql'

print(f'My name is {name}')
print(f'{name} is learning {language}')
print(f'{name} is trying to become {language} expert')
# Out:
# My name is baara
# baara is learning sql
# baara is trying to become sql expert

# %%
'''
    - Update are easy
    - making on update place affect multiple places
'''
