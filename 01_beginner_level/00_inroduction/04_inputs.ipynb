# %%
'''
input() - inbuilt python function ti get something from the user

'''

# %%
name = input(f'enter your name')
country = input(f'Your country')

print(f'{name} from {country}')

# %%
'''
    - input it used to make the program interactive
    - static vs dynamic
'''
