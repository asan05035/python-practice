# %%
'''
Print()
    - Used to display messages on the output screen
'''

# %%
print(f'A/B testing')
x = 6
print(f'completed in {x} seconds')
# Out:
# A/B testing
# completed in 6 seconds

# %%
'''
Escpae sequenec is sued to give extra job
- \n
- \t
- \\
- \'
- \"
'''
